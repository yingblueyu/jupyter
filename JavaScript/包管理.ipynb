// %% [markdown]
// ## npm
//
// npm -l // list of npm commands with brief explanations.
//
// npm init // initializes a Node.js application and create a package.json file
//
// npm config get registry //仓库位置
// npm config set registry https://registry.npm.taobao.org
// npm config set registry https://registry.npmjs.org
// npm config list
//
//
//
// npm -l // list of npm commands with brief explanations.
//
// npm init // initializes a Node.js application and create a package.json file
// ```
// npm config get registry //仓库位置
// npm config set registry https://registry.npm.taobao.org
// npm config set registry https://registry.npmjs.org
// npm config list
// ```
//
//
// ```
// # 设置代理
// npm config set proxy http://username:password@server:port
// npm confit set https-proxy http://username:password@server:port
// npm config set registry https://registry.npmjs.org
//
// # 取消代理
// npm config delete proxy
// npm config delete https-proxy
// ```
//
//
// ```
// npm install -g --save --save-dev ***
// npm install --only=dev
// npm uninstall -g
// npm update *** --save
//
// npm list -g # 全局库位置
// ```

// %% [markdown]
// ## yarn
//
// yarn config get registry
// yarn config set registry https://registry.npm.taobao.org
// yarn config set registry https://registry.yarnpkg.com
// yarn config list
//
// ```
// yarn init 初始化新项目
// yarn add package@version 添加包
// yarn add package --dev
// yarn global add ***
// yarn upgrade package
// yarn remove package
// yarn 项目的全部依赖
// yarn <command> --verbose
//
// yarn run
//
// yarn global add [--prefix]
// yarn global dir   // 全局安装位置
// ```

// %% [markdown]
// ## require
// Node looks for module in node_modules, using following search hierarchy
// 1. a node_module sub directory local to application.
// 2. a node_module sub directory in the parent directory to the current app.
// 3. continuing up the parent sub directory, until top-levell.
// 4. looking for the module intalled globally.

// %% [markdown]
// ## CommonJs规范
//
// - module.exports导出模块
// - require导入模块
//
// ```javascript
// 	 module. exports = {
// 	   title: 'My name is module',
// 	   say: function() { console. log(' log from module. js'); }
//    }
//
//    var myModule = require('./ module');
//    myModule.say();
//    console. log( myModule. title);
// ```

// %% [markdown]
// ## 包管理
//
// CommonJS specification:
//
// CommonJS:
// exports.XX = XX
//
// CommonJS2
// module.exports = XX
// const moduleA = require('./moduleA');
//
// ---
//
// ESMAScript modules; ESM:
// export function hello() {};
//
// export default {aaa, bbb, ccc};
// import c from 'fff'
// c.aaa
//
// export {aaa, bbb, ccc};
// import {aaa, bbb, ccc as ddd} from 'fff'
//
// import { readFile } from 'fs';
// import React from 'reac
